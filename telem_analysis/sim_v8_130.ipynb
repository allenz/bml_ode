# %%
import matplotlib.pyplot as plot
# %matplotlib inline
import numpy as np
import pandas as pd
import base

# %%
# Extended telemetry with correct mass
# t = base.process('sim_v8_235.csv')
t = base.process('sim_v8_130.csv')
base.setPlot(plot)

# %%
base.plotPAT(t, xlim=[3000,6000])

# %% [markdown]
# # Position and Angle

# %%
# The VelociROACH moves 0.1 m/s at 1.5 Hz; turns 180 degrees in 10 s
plot.plot(t.time, t.x, 'r', t.time, t.y, 'g', t.time, t.g, 'b', t.time, t.AngleZ, 'c')
plot.xlabel('Time (ms)')
plot.ylabel('Position (m) / Angle (rad)')
plot.legend(['x','y','Yaw', 'Est yaw'], loc=2)

# %%
t['VelX'] = t.x.diff()
t['VelY'] = t.y.diff()
plot.plot(t.time, np.sqrt(np.square(t[['VelX','VelY']]).sum(axis=1)), 'b')

# %%
# Turns left
plot.plot(t.x, t.y, 'b')
plot.xlabel('x (m)')
plot.ylabel('y (m)')

# %%
# Complicated dynamics: low-frequency changes, not periodic
# Est Roll from gyro drifts.. should remain near 0 because robot is on the ground
plot.plot(t.time, t.a, 'r', t.time, t.b, 'b', t.time, t.AngleY, 'g')
plot.xlabel('Time (ms)')
plot.ylabel('Angle (rad)')
plot.legend(['Pitch','Roll','Est Roll'], loc=2)

# %%
# Pitches forward when switching off, especially pronounced on right side
plot.plot(t.time, t.a, 'r', t.time, t.b, 'b')
plot.xlim([10e3,13e3])
plot.axhline(color='m')
plot.xlabel('Time (ms)')
plot.ylabel('Angle (rad)')
plot.legend(['Pitch','Roll'], loc=2)

# %% [markdown]
# # VelociROACH dynamics

# %%
base.plotFXYZ(t)
# Out:
# Sample force sensor readout; total force = norm(Fx, Fy, Fz)

# %%
base.plotForceLR(t, xlim=[3000,6000])
# Out:
# Alternating tripod gait: roll right (positive) = LM force. Roll left = LF and LB force

# %%
# Torques don't seem very useful
plot.plot(t.time, t.b/20, 'k', t.time, t.fRF, 'b', t.time, t.fRB, 'g',
          t.time, t.torqueR*50, 'c', t.time, t.torqueR1*50, 'y')
plot.xlim([4e3,7e3])
plot.xlabel('Time (ms)')
plot.ylabel('Angle (rad/20) / Force (N)')
plot.legend(['Roll','Force RF','Force RB','Torque RF','Torque RB'])

# %%
# Sum of forward and back motor torque, right side, still not useful
plot.plot(t.time, t.b/20, 'k', t.time, t.fRF, 'b', t.time, t.fRB, 'g',
          t.time, (t.torqueR+t.torqueR1)*50, 'y')
plot.xlim([4e3,7e3])
plot.xlabel('Time (ms)')
plot.ylabel('Angle (rad/20) / Force (N)')
plot.legend(['Roll','Force RF','Force RB','Torque R'])

# %%
from matplotlib.collections import LineCollection
points = np.array([t.b, t.z]).transpose().reshape(-1,1,2)
print(points.shape)
segs = np.concatenate([points[:-1],points[1:]],axis=1)
lc = LineCollection(segs, cmap=plot.get_cmap('jet'))
lc.set_array(t) # color the segments by our parameter

# plot the collection
plot.gca().add_collection(lc) # add the collection to the plot
# plot.plot(t.b, t.z, 'b')
# Out:
# (1216, 1, 2)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\az\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     305                 pass
#     306             else:
# --> 307                 return printer(obj)
#     308             # Finally look for special method names
#     309             method = get_real_method(obj, self.print_method)
#
# C:\Users\az\Anaconda3\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     225
#     226     if 'png' in formats:
# --> 227         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     228     if 'retina' in formats or 'png2x' in formats:
#     229         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# C:\Users\az\Anaconda3\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     117
#     118     bytes_io = BytesIO()
# --> 119     fig.canvas.print_figure(bytes_io, **kw)
#     120     data = bytes_io.getvalue()
#     121     if fmt == 'svg':
#
# C:\Users\az\Anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2178                     orientation=orientation,
#    2179                     dryrun=True,
# -> 2180                     **kwargs)
#    2181                 renderer = self.figure._cachedRenderer
#    2182                 bbox_inches = self.figure.get_tightbbox(renderer)
#
# C:\Users\az\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     525
#     526     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 527         FigureCanvasAgg.draw(self)
#     528         renderer = self.get_renderer()
#     529         original_dpi = renderer.dpi
#
# C:\Users\az\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     472
#     473         try:
# --> 474             self.figure.draw(self.renderer)
#     475         finally:
#     476             RendererAgg.lock.release()
#
# C:\Users\az\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      60     def draw_wrapper(artist, renderer, *args, **kwargs):
#      61         before(artist, renderer)
# ---> 62         draw(artist, renderer, *args, **kwargs)
#      63         after(artist, renderer)
#      64
#
# C:\Users\az\Anaconda3\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1157         dsu.sort(key=itemgetter(0))
#    1158         for zorder, a, func, args in dsu:
# -> 1159             func(*args)
#    1160
#    1161         renderer.close_group('figure')
#
# C:\Users\az\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      60     def draw_wrapper(artist, renderer, *args, **kwargs):
#      61         before(artist, renderer)
# ---> 62         draw(artist, renderer, *args, **kwargs)
#      63         after(artist, renderer)
#      64
#
# C:\Users\az\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2317
#    2318         for zorder, a in dsu:
# -> 2319             a.draw(renderer)
#    2320
#    2321         renderer.close_group('axes')
#
# C:\Users\az\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      60     def draw_wrapper(artist, renderer, *args, **kwargs):
#      61         before(artist, renderer)
# ---> 62         draw(artist, renderer, *args, **kwargs)
#      63         after(artist, renderer)
#      64
#
# C:\Users\az\Anaconda3\lib\site-packages\matplotlib\collections.py in draw(self, renderer)
#     261         renderer.open_group(self.__class__.__name__, self.get_gid())
#     262
# --> 263         self.update_scalarmappable()
#     264
#     265         transform, transOffset, offsets, paths = self._prepare_points()
#
# C:\Users\az\Anaconda3\lib\site-packages\matplotlib\collections.py in update_scalarmappable(self)
#     707             return
#     708         if self._A.ndim > 1:
# --> 709             raise ValueError('Collections can only map rank 1 arrays')
#     710         if not self.check_update("array"):
#     711             return
#
# ValueError: Collections can only map rank 1 arrays

# %%
base.plotBasic(t)
